# %%
#importação 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#importação do cvs
df= pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseMunicipioMensal.csv', sep= ';', encoding='latin1')
df
# Out:
#        fmun_cod                fmun   ano  mes  mes_ano    regiao  hom_doloso  \
# 0       3300100      Angra dos Reis  2014    1  2014m01  Interior          11
# 1       3300159             Aperibé  2014    1  2014m01  Interior           0
# 2       3300209            Araruama  2014    1  2014m01  Interior           2
# 3       3300225               Areal  2014    1  2014m01  Interior           0
# 4       3300233  Armação dos Búzios  2014    1  2014m01  Interior           2
# ...         ...                 ...   ...  ...      ...       ...         ...
# 12599   3306008           Três Rios  2025    5  2025m05  Interior           5
# 12600   3306107             Valença  2025    5  2025m05  Interior           4
# 12601   3306156           Varre-Sai  2025    5  2025m05  Interior           0
# 12602   3306206           Vassouras  2025    5  2025m05  Interior           0
# 12603   3306305       Volta Redonda  2025    5  2025m05  Interior           5
#
#        lesao_corp_morte  latrocinio  cvli  ...  cmp  cmba  ameaca  \
# 0                     0           0    11  ...    8     0      98
# 1                     0           0     0  ...    0     0       0
# 2                     0           0     2  ...    5     0      91
# 3                     0           0     0  ...    0     0       0
# 4                     0           0     2  ...    3     2      46
# ...                 ...         ...   ...  ...  ...   ...     ...
# 12599                 0           0     5  ...   15     0      60
# 12600                 0           0     4  ...    9     0      32
# 12601                 0           0     0  ...    0     0       8
# 12602                 0           0     0  ...    3     0      17
# 12603                 0           0     5  ...   15     0     185
#
#        pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 0                         13                 3                0
# 1                          0                 0                0
# 2                         10                 1                0
# 3                          0                 0                0
# 4                          0                 0                0
# ...                      ...               ...              ...
# 12599                      1                 0                0
# 12600                      1                 0                0
# 12601                      0                 0                0
# 12602                      1                 0                0
# 12603                     14                 0                0
#
#        pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 0                              0                      0                   561
# 1                              0                      0                     0
# 2                              0                      0                   480
# 3                              0                      0                     0
# 4                              0                      0                   309
# ...                          ...                    ...                   ...
# 12599                          0                      0                   493
# 12600                          0                      0                   257
# 12601                          0                      0                    23
# 12602                          0                      0                   131
# 12603                          0                      0                  1519
#
#        fase
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# ...     ...
# 12599     2
# 12600     2
# 12601     2
# 12602     2
# 12603     2
#
# [12604 rows x 60 columns]

# %%
#filtro dos municipios da baixada
df_baixada = df.loc[df['fmun'].isin(['Belford Roxo','Duque de Caxias','Guapimirim','Itaguaí','Japeri','Magé','Mesquita','Nilópolis','Nova Iguaçu','Paracambi','Queimados','São João de Meriti','Seropédica'])]
df_baixada
# Out:
#        fmun_cod                fmun   ano  mes  mes_ano              regiao  \
# 8       3300456        Belford Roxo  2014    1  2014m01  Baixada Fluminense
# 24      3301702     Duque de Caxias  2014    1  2014m01  Baixada Fluminense
# 26      3301850          Guapimirim  2014    1  2014m01  Baixada Fluminense
# 29      3302007             Itaguaí  2014    1  2014m01  Baixada Fluminense
# 34      3302270              Japeri  2014    1  2014m01  Baixada Fluminense
# ...         ...                 ...   ...  ...      ...                 ...
# 12561   3303500         Nova Iguaçu  2025    5  2025m05  Baixada Fluminense
# 12562   3303609           Paracambi  2025    5  2025m05  Baixada Fluminense
# 12572   3304144           Queimados  2025    5  2025m05  Baixada Fluminense
# 12586   3305109  São João de Meriti  2025    5  2025m05  Baixada Fluminense
# 12593   3305554          Seropédica  2025    5  2025m05  Baixada Fluminense
#
#        hom_doloso  lesao_corp_morte  latrocinio  cvli  ...  cmp  cmba  ameaca  \
# 8              29                 0           0    29  ...   16     0     231
# 24             37                 0           0    37  ...   56     0     447
# 26              1                 0           0     1  ...    2     0      35
# 29              9                 0           0     9  ...    6     0      57
# 34              5                 0           0     5  ...   10     0      50
# ...           ...               ...         ...   ...  ...  ...   ...     ...
# 12561          28                 0           0    28  ...   40     6     293
# 12562           0                 0           0     0  ...    1     0      15
# 12572           1                 1           1     3  ...    9     4      68
# 12586           6                 0           1     7  ...   20     0      94
# 12593           1                 0           0     1  ...    4     1      24
#
#        pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 8                         22                 3                0
# 24                        43                 3                0
# 26                         4                 0                0
# 29                         8                 0                1
# 34                         3                 1                0
# ...                      ...               ...              ...
# 12561                     35                 2                0
# 12562                      1                 0                0
# 12572                      3                 0                0
# 12586                     16                 1                0
# 12593                      3                 0                0
#
#        pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 8                              0                      0                  1367
# 24                             0                      0                  4247
# 26                             0                      0                   137
# 29                             0                      0                   461
# 34                             0                      0                   298
# ...                          ...                    ...                   ...
# 12561                          0                      0                  3222
# 12562                          0                      0                   126
# 12572                          0                      0                   480
# 12586                          0                      0                  1284
# 12593                          0                      0                   273
#
#        fase
# 8         3
# 24        3
# 26        3
# 29        3
# 34        3
# ...     ...
# 12561     2
# 12562     2
# 12572     2
# 12586     2
# 12593     2
#
# [1763 rows x 60 columns]

# %%
#juncao dos municipios da baixada e 
df_apre = df_baixada.groupby('fmun')['aaapai' ].sum().reset_index()
df_apre= df_apre.sort_values(by= 'aaapai')
df_apre
# Out:
#                   fmun  aaapai
# 2           Guapimirim     187
# 9            Paracambi     190
# 11          Seropédica     192
# 4               Japeri     257
# 10           Queimados     364
# 7            Nilópolis     400
# 3              Itaguaí     423
# 6             Mesquita     758
# 5                 Magé     802
# 0         Belford Roxo    1513
# 12  São João de Meriti    2039
# 8          Nova Iguaçu    2496
# 1      Duque de Caxias    2971

# %%
#separar só as apreensoes
apre= df_apre['aaapai']
dados= np.array(apre)
dados.sort() #sort serve para ordenar do menor para o maior
dados
# Out:
# array([ 187,  190,  192,  257,  364,  400,  423,  758,  802, 1513, 2039,
#        2496, 2971])

# %%
q3= np.percentile(dados, 75)
q3
# Out:
# np.float64(1513.0)

# %%
df_maior= df_apre.loc[(df_apre['aaapai'] >= q3)]
df_maior
# Out:
#                   fmun  aaapai
# 0         Belford Roxo    1513
# 12  São João de Meriti    2039
# 8          Nova Iguaçu    2496
# 1      Duque de Caxias    2971

# %%
df_apre.tail(5)
# Out:
#                   fmun  aaapai
# 5                 Magé     802
# 0         Belford Roxo    1513
# 12  São João de Meriti    2039
# 8          Nova Iguaçu    2496
# 1      Duque de Caxias    2971

# %%
#grafico de roubo
df_apre.plot(x='fmun', y='aaapai', kind= 'barh')
plt.title('Apreensão de menores')
plt.xlabel('\nQuantidade de apreensões\n')
plt.ylabel('\nMunicípios\n')
plt.show()

# %%
#array de apreensões
array= df_apre['aaapai']
dados= np.array(array)

# %%
#calcular média
media= np.mean(dados)
media
# Out:
# np.float64(968.6153846153846)

# %%
#calcular mediana 
mediana= np.median(dados)
mediana
# Out:
# np.float64(423.0)

# %%
#calcular a distancia relativa
distancia= (media - mediana) / mediana *100
distancia
# Out:
# np.float64(128.98708856155665)
