# %%
#importação 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#importação do csv
df= pd.read_csv('dados_saude_estilo_vida.csv', sep= ',', encoding='latin1')
df
# Out:
#      Atividade FÃ­sica (min/dia)    IMC  Consumo de Frutas (porÃ§Ãµes/dia)  \
# 0                           35.0  13.92                                2.0
# 1                           29.0  16.62                                3.0
# 2                           36.0  11.82                                2.0
# 3                           45.0   6.74                                3.0
# 4                           28.0  16.87                                1.0
# ..                           ...    ...                                ...
# 995                         27.0  17.48                                3.0
# 996                         48.0   5.99                                3.0
# 997                         36.0  10.91                                2.0
# 998                         24.0  17.69                                3.0
# 999                         36.0  11.39                                3.0
#
#      NÃ­vel de Estresse  Consumo CalÃ³rico (kcal/dia)  Horas de Sono  \
# 0                  2.39                        2053.0           7.31
# 1                  3.28                        2163.0           7.12
# 2                  3.92                        2120.0           6.32
# 3                  6.08                        2115.0           6.62
# 4                  5.22                        2032.0           7.32
# ..                  ...                           ...            ...
# 995                4.11                        2170.0           7.26
# 996                1.94                        2131.0           8.19
# 997                4.15                        2420.0           6.56
# 998                5.64                        2258.0           7.11
# 999                4.51                        2029.0           6.51
#
#      Renda Mensal (R$)
# 0               3940.0
# 1               4302.0
# 2               3915.0
# 3               4236.0
# 4               3510.0
# ..                 ...
# 995             4479.0
# 996             4783.0
# 997             3774.0
# 998             4666.0
# 999             4502.0
#
# [1000 rows x 7 columns]

# %%
plt.scatter(df['Atividade FÃ­sica (min/dia)'], df['IMC'])

# %%
plt.scatter(df['NÃ­vel de Estresse'], df['Horas de Sono'])
