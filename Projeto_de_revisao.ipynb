# %%
#importação 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#importação do cvs
df= pd.read_csv('DOMensalEstadoDesde1991.csv', sep= ';', encoding='latin1')
df
# Out:
#       ano  mes  hom_doloso  lesao_corp_morte  latrocinio   cvli  \
# 0    1991    1         657               NaN          15    NaN
# 1    1991    2         732               NaN          17    NaN
# 2    1991    3         713               NaN          25    NaN
# 3    1991    4         634               NaN          20    NaN
# 4    1991    5         650               NaN          20    NaN
# ..    ...  ...         ...               ...         ...    ...
# 408  2025    1         317              10.0           6  333.0
# 409  2025    2         245               6.0           6  257.0
# 410  2025    3         271              10.0           7  288.0
# 411  2025    4         205               6.0           6  217.0
# 412  2025    5         255               5.0           4  264.0
#
#      hom_por_interv_policial  letalidade_violenta  tentat_hom  \
# 0                        NaN                  672         162
# 1                        NaN                  749         175
# 2                        NaN                  738         216
# 3                        NaN                  654         200
# 4                        NaN                  670         146
# ..                       ...                  ...         ...
# 408                     68.0                  401         342
# 409                     79.0                  336         324
# 410                     59.0                  347         347
# 411                     80.0                  297         296
# 412                     44.0                  308         279
#
#      lesao_corp_dolosa  ...     cmp   cmba  ameaca  pessoas_desaparecidas  \
# 0                 3051  ...     NaN    NaN     NaN                    NaN
# 1                 3421  ...     NaN    NaN     NaN                    NaN
# 2                 3613  ...     NaN    NaN     NaN                    NaN
# 3                 3211  ...     NaN    NaN     NaN                    NaN
# 4                 3051  ...     NaN    NaN     NaN                    NaN
# ..                 ...  ...     ...    ...     ...                    ...
# 408               6055  ...   927.0  116.0  6159.0                  552.0
# 409               5973  ...   972.0  139.0  6149.0                  520.0
# 410               6249  ...  1102.0  136.0  6406.0                  622.0
# 411               4987  ...   933.0  105.0  5498.0                  498.0
# 412               4964  ...  1022.0  115.0  5559.0                  496.0
#
#      encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 217              NaN                        NaN
# 1                 209              NaN                        NaN
# 2                 188              NaN                        NaN
# 3                 140              NaN                        NaN
# 4                  78              NaN                        NaN
# ..                ...              ...                        ...
# 408                40              3.0                        2.0
# 409                50              2.0                        0.0
# 410                40              3.0                        1.0
# 411                31              1.0                        0.0
# 412                37              5.0                        0.0
#
#      pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                      NaN                   NaN     3
# 1                      NaN                   NaN     3
# 2                      NaN                   NaN     3
# 3                      NaN                   NaN     3
# 4                      NaN                   NaN     3
# ..                     ...                   ...   ...
# 408                    0.0               81562.0     3
# 409                    2.0               80306.0     3
# 410                    0.0               84129.0     3
# 411                    0.0               75761.0     2
# 412                    0.0               80424.0     2
#
# [413 rows x 56 columns]

# %%
#filtro do ano
df_ano= df.loc[(df['ano'] >= 2015)]
df_ano
# Out:
#       ano  mes  hom_doloso  lesao_corp_morte  latrocinio   cvli  \
# 288  2015    1         439               1.0          11  451.0
# 289  2015    2         326               8.0          10  344.0
# 290  2015    3         382               1.0          15  398.0
# 291  2015    4         339               4.0          21  364.0
# 292  2015    5         347               2.0           8  357.0
# ..    ...  ...         ...               ...         ...    ...
# 408  2025    1         317              10.0           6  333.0
# 409  2025    2         245               6.0           6  257.0
# 410  2025    3         271              10.0           7  288.0
# 411  2025    4         205               6.0           6  217.0
# 412  2025    5         255               5.0           4  264.0
#
#      hom_por_interv_policial  letalidade_violenta  tentat_hom  \
# 288                     65.0                  516         618
# 289                     83.0                  427         479
# 290                     54.0                  452         545
# 291                     59.0                  423         490
# 292                     44.0                  401         482
# ..                       ...                  ...         ...
# 408                     68.0                  401         342
# 409                     79.0                  336         324
# 410                     59.0                  347         347
# 411                     80.0                  297         296
# 412                     44.0                  308         279
#
#      lesao_corp_dolosa  ...     cmp   cmba  ameaca  pessoas_desaparecidas  \
# 288               7747  ...  1496.0   58.0  7272.0                  577.0
# 289               6757  ...  1431.0   57.0  6135.0                  500.0
# 290               6795  ...  1759.0   87.0  7088.0                  593.0
# 291               6293  ...  1958.0   57.0  6259.0                  504.0
# 292               5844  ...  1878.0   57.0  5992.0                  520.0
# ..                 ...  ...     ...    ...     ...                    ...
# 408               6055  ...   927.0  116.0  6159.0                  552.0
# 409               5973  ...   972.0  139.0  6149.0                  520.0
# 410               6249  ...  1102.0  136.0  6406.0                  622.0
# 411               4987  ...   933.0  105.0  5498.0                  498.0
# 412               4964  ...  1022.0  115.0  5559.0                  496.0
#
#      encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 288                54              2.0                        3.0
# 289                43              2.0                        1.0
# 290                55             13.0                        3.0
# 291                38              1.0                        2.0
# 292                44              4.0                        4.0
# ..                ...              ...                        ...
# 408                40              3.0                        2.0
# 409                50              2.0                        0.0
# 410                40              3.0                        1.0
# 411                31              1.0                        0.0
# 412                37              5.0                        0.0
#
#      pol_civis_mortos_serv  registro_ocorrencias  fase
# 288                    0.0               71617.0     3
# 289                    0.0               65058.0     3
# 290                    0.0               69267.0     3
# 291                    0.0               63077.0     3
# 292                    1.0               64230.0     3
# ..                     ...                   ...   ...
# 408                    0.0               81562.0     3
# 409                    2.0               80306.0     3
# 410                    0.0               84129.0     3
# 411                    0.0               75761.0     2
# 412                    0.0               80424.0     2
#
# [125 rows x 56 columns]

# %%
#juncao do ano e recuperação de veículos
df_rec = df_ano.groupby('ano')['recuperacao_veiculos'].sum().reset_index()
df_rec= df_rec.sort_values(by= 'ano')
df_rec
# Out:
#      ano  recuperacao_veiculos
# 0   2015                 23663
# 1   2016                 28690
# 2   2017                 37630
# 3   2018                 36448
# 4   2019                 26863
# 5   2020                 15945
# 6   2021                 13702
# 7   2022                 13210
# 8   2023                 14675
# 9   2024                 19034
# 10  2025                  7444

# %%
#grafico de recuperação
df_ano.plot(x='ano', y='recuperacao_veiculos',kind= 'line')
plt.title('Recuperação de veículos')
plt.xlabel('\nAno\n')
plt.ylabel('\nquantidade de veículos\n')
plt.show()

# %%
#juncao do ano, furtos e roubos
df_vei = df_ano.groupby('ano')[['furto_veiculos' ,'roubo_veiculo']].sum().reset_index()
df_vei
# Out:
#      ano  furto_veiculos  roubo_veiculo
# 0   2015           16944          31035
# 1   2016           16759          41696
# 2   2017           15708          54366
# 3   2018           15794          52097
# 4   2019           15595          39749
# 5   2020           12895          25425
# 6   2021           14428          24332
# 7   2022           16864          25198
# 8   2023           16577          22248
# 9   2024           17337          30930
# 10  2025            7073           9840

# %%
#grafico dos furtos
df_ano.plot(x='ano', y='furto_veiculos',kind= 'line')
plt.title('Furtos de veículos')
plt.xlabel('\nAno\n')
plt.ylabel('\nquantidade de veículos\n')
plt.show()

# %%
#grafico de roubo
df_ano.plot(x='ano', y='roubo_veiculo',kind= 'line')
plt.title('Roubo de veículos')
plt.xlabel('\nAno\n')
plt.ylabel('\nquantidade de veículos\n')
plt.show()

# %%
#relação entre furtos e recuperação de veículos
plt.scatter(df_ano['furto_veiculos'] , df_ano['recuperacao_veiculos'])
plt.show()

# %%
#relação entre roubos e recuperação 
plt.scatter(df_ano['roubo_veiculo'] , df_ano['recuperacao_veiculos'])
plt.show()

# %%
#array de recuperação
array1= df_ano['recuperacao_veiculos']
dados1= np.array(array1)

# %%
#calcular média de recuperação
media= np.mean(dados1)
media
# Out:
# np.float64(1898.432)

# %%
#calcular mediana de recuperação
mediana= np.median(dados1)
mediana
# Out:
# np.float64(1813.0)

# %%
#calcular a distancia relativa
distancia= (media - mediana) / mediana *100
distancia
# Out:
# np.float64(4.71218974076117)

# %%
#array de roubo
array2= df_ano['roubo_veiculo']
dados2= np.array(array2)

# %%
#calcular média do roubo
media= np.mean(dados2)
media
# Out:
# np.float64(2855.328)

# %%
#calcular mediana do roubo
mediana= np.median(dados2)
mediana
# Out:
# np.float64(2500.0)

# %%
#calcular a distancia relativa
distancia= (media - mediana) / mediana *100
distancia
# Out:
# np.float64(14.213119999999998)

# %%
#array de furto
array3= df_ano['furto_veiculos']
dados3= np.array(array3)

# %%
#calcular média de furto
media= np.mean(dados3)
media
# Out:
# np.float64(1327.792)

# %%
#calcular mediana de furto
mediana= np.median(dados3)
mediana
# Out:
# np.float64(1353.0)

# %%
#calcular a distancia relativa
distancia= (media - mediana) / mediana *100
distancia
# Out:
# np.float64(-1.8631189948263178)
