# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('pesquisa_satisfacao.csv', sep= ';')
df
# Out:
#          Cliente Satisfação  Tempo de Espera (min)
# 0         Naruto       Alta                      8
# 1           Goku       Alta                     10
# 2         Vegeta      Média                     17
# 3         Sasuke       Alta                      8
# 4         Madara      Média                     15
# 5          Luffy      Baixa                      5
# 6           Zoro       Alta                     22
# 7          Sanji      Baixa                     26
# 8         Yusuke      Baixa                     14
# 9         Kurama      Média                      8
# 10           Gon      Média                     12
# 11          Eren      Média                     28
# 12        Mikasa       Alta                      6
# 13         Light       Alta                     10
# 14             L       Alta                     19
# 15  Peter Parker      Baixa                     21
# 16   Bruce Wayne       Alta                     18
# 17        Thanos      Média                     19
# 18       Edmundo      Baixa                     13
# 19       Vegetti      Média                     19

# %%
df_s= df.sort_values(by='Tempo de Espera (min)', ascending = True)
df_s
# Out:
#          Cliente Satisfação  Tempo de Espera (min)
# 5          Luffy      Baixa                      5
# 12        Mikasa       Alta                      6
# 3         Sasuke       Alta                      8
# 0         Naruto       Alta                      8
# 9         Kurama      Média                      8
# 13         Light       Alta                     10
# 1           Goku       Alta                     10
# 10           Gon      Média                     12
# 18       Edmundo      Baixa                     13
# 8         Yusuke      Baixa                     14
# 4         Madara      Média                     15
# 2         Vegeta      Média                     17
# 16   Bruce Wayne       Alta                     18
# 17        Thanos      Média                     19
# 19       Vegetti      Média                     19
# 14             L       Alta                     19
# 15  Peter Parker      Baixa                     21
# 6           Zoro       Alta                     22
# 7          Sanji      Baixa                     26
# 11          Eren      Média                     28

# %%
tempo= df['Tempo de Espera (min)']

dados= np.array(tempo)
dados
# Out:
# array([ 8, 10, 17,  8, 15,  5, 22, 26, 14,  8, 12, 28,  6, 10, 19, 21, 18,
#        19, 13, 19])

# %%
q1= np.percentile(dados, 25)
q1
# Out:
# np.float64(9.5)

# %%
cliente= df_s[['Cliente', 'Tempo de Espera (min)']]
cliente_q1= cliente[cliente['Tempo de Espera (min)'] <=q1]
cliente_q1
# Out:
#    Cliente  Tempo de Espera (min)
# 5    Luffy                      5
# 12  Mikasa                      6
# 3   Sasuke                      8
# 0   Naruto                      8
# 9   Kurama                      8

# %%
cliente_q1.plot(x='Cliente', y='Tempo de Espera (min)', kind='bar')
plt.title('Clientes que tiveram o menor tempo de espera')
plt.xlabel('\ncliente\n')
plt.ylabel('\nTempo de espera\n')
plt.show()
